# %% [markdown]
# # **Data Ingestion**

# %% [markdown]
# ### Document datastructure

# %%
from langchain_core.documents import Document
import langchain

# %%
doc = Document(
    page_content="This is the content of the document.",
    metadata={"source": "example.txt", "author": "John Doe", "page": 1, "date_created": "2024-06-01"},
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'author': 'John Doe', 'page': 1, 'date_created': '2024-06-01'}, page_content='This is the content of the document.')

# %%
### create a simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath, content in sample_texts.items():
    with open(filepath, "w") as f:
        f.write(content)

print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/text_files/python_intro.txt")
docs = loader.load()
print(docs[0].page_content[:100], "\n")
print("+=+=+=+"*50  + "\n")
print(docs)
# Out:
# Python Programming Introduction
#
# Python is a high-level, interpreted programming language known for
#
# +=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=++=+=+=+
#
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader("../data/text_files", glob="**/*.txt", loader_cls = TextLoader, loader_kwargs={"encoding": "utf-8"}, show_progress=False)

dir_docs = dir_loader.load()
print(dir_docs)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader = DirectoryLoader("../data/pdf_files", glob="**/*.pdf", loader_cls = PyMuPDFLoader, show_progress=False)

dir_docs = dir_loader.load()
print(dir_docs)
# Out:
# [Document(metadata={'producer': 'Qt 4.8.7', 'creator': 'wkhtmltopdf 0.12.4', 'creationdate': '2026-05-16T17:04:14+00:00', 'source': '..\\data\\pdf_files\\osqb.pdf', 'file_path': '..\\data\\pdf_files\\osqb.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Markdown To PDF', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20260516170414Z', 'page': 0}, page_content='Operating Systems — Unit-wise & Topic-wise Repeated Question Bank\nUNIT 1 — INTRODUCTION & PROCESS MANAGEMENT\nTopic: Operating System Basics\n1 Mark Questions\n1. Operating System is a/an __________ between user and hardware of a system.\n2. The main purpose of an operating system is to:\n3. Which of the following is not a feature of Unix?\n4. Context-switch times are highly dependent on __________.\nTopic: PCB & Process\n1 Mark Questions\n1. A Program in execution is known as __________.\n2. A process control block (PCB) also called a __________.\n3. The Process Control Block contains all of the following except:\n2 Mark Questions\n1. What is the relationship between threads and processes?\n2. Define context switching.\n3. Differentiate between multitasking and multiprocessing operating systems.\n6 Mark Questions\n1. Explain the concept of process. Also describe the contents of a Process Control Block (PCB).\n2. Explain the concept of process. Also describe the contents of a Process Control Block (PCB).\n10 Mark Questions\n1. Explain the functions of Operating System.\n2. Explain the features of Batch Operating System with advantages and disadvantages.\n3. Discuss the role of kernel in operating system. Explain the difference between monolithic kernel and microkernel.\n4. Illustrate the layered structure of an operating system and explain the role of each layer.\nTopic: Interrupts, System Calls & Virtual Machine\n6 Mark Questions\n1. What is System Call? Explain with example.\n2. What is Time-sharing Operating System? How does it manage processes?\n3. Explain the role of Operating System as I/O operation. Also explain the concept of context switching.\n10 Mark Questions\n1. Describe Interrupts and its different types. Explain Maskable and Non-maskable Interrupts.\n2. Describe the use of Fork and Executive System Calls. Explain Virtual Machine and its concept with history.\nUNIT 2 — PROCESS SCHEDULING\nTopic: Scheduling Basics\n1 Mark Questions\n1. What type of scheduling is Round Robin scheduling?\n2. Which module gives control of CPU to the process selected by short-term scheduler?\n3. The primary distinction between short-term scheduler and long-term scheduler is __________.'), Document(metadata={'producer': 'Qt 4.8.7', 'creator': 'wkhtmltopdf 0.12.4', 'creationdate': '2026-05-16T17:04:14+00:00', 'source': '..\\data\\pdf_files\\osqb.pdf', 'file_path': '..\\data\\pdf_files\\osqb.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Markdown To PDF', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20260516170414Z', 'page': 1}, page_content='4. Identify the primary design goal of Round Robin scheduling algorithm.\n5. Identify the correct definition of context switch in process management.\n2 Mark Questions\n1. Define Swap-in and Swap-out.\n2. Define Dispatch Latency.\n3. Differentiate between preemptive and non-preemptive scheduling.\n6 Mark Questions\n1. Explain Shortest Job First CPU scheduling with example.\n2. Explain Round Robin Scheduling with example.\n3. Explain Round Robin Scheduling with example.\n4. Explain FCFS and SJF scheduling algorithms with advantages and disadvantages.\n5. Explain FCFS and SJF scheduling algorithms with advantages and disadvantages.\nTopic: Scheduling Numericals\n10 Mark Questions\n1. Suppose that the following processes arrive for execution at the times indicated. Each process will run for the amount of time listed. Use non-preemptive\nscheduling.\nProcess\nArrival\nTime\nBurst\nTime\nP1\n0.0\n8\nP2\n0.4\n4 ...
